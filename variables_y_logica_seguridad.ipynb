# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelechoe/ciberseguridad-python/blob/main/variables_y_logica_seguridad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
device_id = "72e08x0"
print(device_id)
# Out:
# 72e08x0

# %%
device_id = "72e08x0"
device_id_type = type(device_id)
print(device_id_type)
# Out:
# <class 'str'>

# %%
username_list = ["m.alvarez", "d.franco", "valentina.rios", "santiago.gomez", "k.torres"]
print(username_list)
# Out:
# ['m.alvarez', 'd.franco', 'valentina.rios', 'santiago.gomez', 'k.torres']

# %%
username_list = ["m.alvarez", "d.franco", "valentina.rios", "santiago.gomez", "k.torres"]
username_list_type = type(username_list)
print(username_list_type)
# Out:
# <class 'list'>

# %%
username_list = ["m.alvarez", "d.franco", "valentina.rios", "santiago.gomez", "k.torres"]
username_list = ["m.alvarez", "d.franco", "valentina.rios", "santiago.gomez", "k.torres", "h.santamaria"]
print(username_list)
# Out:
# ['m.alvarez', 'd.franco', 'valentina.rios', 'santiago.gomez', 'k.torres', 'h.santamaria']

# %%
max_logins = 3
max_logins_type = type(max_logins)
print(max_logins_type)
# Out:
# <class 'int'>

# %%
login_attempts = 2
login_attempts_type = type(login_attempts)
print(login_attempts_type)
# Out:
# <class 'int'>

# %%
max_logins = 3
login_attempts = 2
print(login_attempts <= max_logins)
# Out:
# True

# %%
max_logins = 3
login_attempts = 4
print(login_attempts <= max_logins)
# Out:
# False

# %%
login_status = False
login_status_type = type(login_status)
print(login_status_type)
# Out:
# <class 'bool'>
