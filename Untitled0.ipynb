# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelechoe/ciberseguridad-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(3):
    print("connection could not be established.")
# Out:
# connection could not be established.
# connection could not be established.
# connection could not be established.

# %%
connection_attempts = 5
for i in range(connection_attempts):
    print("connection could not be established.")
# Out:
# connection could not be established.
# connection could not be established.
# connection could not be established.
# connection could not be established.
# connection could not be established.

# %%
connection_attempts = 0
while connection_attempts < 3:
    print("connection could not be established.")
    connection_attempts = connection_attempts + 1
# Out:
# connection could not be established.
# connection could not be established.
# connection could not be established.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
ip_addresses = ["192.168.142.245","192.168.109.50","192.168.86.232","192.168.131.147","192.168.205.12","192.168.200.48"]
for i in ip_addresses:
    print(i)
# Out:
# 192.168.142.245
# 192.168.109.50
# 192.168.86.232
# 192.168.131.147
# 192.168.205.12
# 192.168.200.48

# %%
allow_list = ["192.168.243.140","192.168.205.12","192.168.151.162","192.168.178.71","192.168.86.232","192.168.3.24","192.168.170.243","192.168.119.173"]
ip_addresses = ["192.168.142.245","192.168.109.50","192.168.86.232","192.168.131.147","192.168.205.12","192.168.200.98"]
for i in ip_addresses:
    if i in allow_list:
       print("ip address is allowed")
    else:
       print("ip address is not allowed")
# Out:
# ip address is not allowed
# ip address is not allowed
# ip address is allowed
# ip address is not allowed
# ip address is allowed
# ip address is not allowed

# %%
allow_list = ["192.168.243.140","192.168.205.12","192.168.151.162","192.168.178.71","192.168.86.232","192.168.3.24","192.168.170.243","192.168.119.173"]
ip_addresses = ["192.168.142.245","192.168.109.50","192.168.86.232","192.168.131.147","192.168.205.12","192.168.200.98"]
for i in ip_addresses:
    if i in allow_list:
       print("ip addresses is allowed")
else:
    print("ip address is not allowed")
    print("further investigation of login activity required")
# Out:
# ip addresses is allowed
# ip addresses is allowed
# ip address is not allowed
# further investigation of login activity required

# %%
i = 5000
while i <= 5150:
    print(i)
    i = i + 5
# Out:
# 5000
# 5005
# 5010
# 5015
# 5020
# 5025
# 5030
# 5035
# 5040
# 5045
# 5050
# 5055
# 5060
# 5065
# 5070
# 5075
# 5080
# 5085
# 5090
# 5095
# 5100
# 5105
# 5110
# 5115
# 5120
# 5125
# 5130
# 5135
# 5140
# 5145
# 5150

# %%
i = 5000
while i <= 5150:
    print(i)
    if i == 5100:
       print("only 10 valid employee ids remaining")
    i = i + 5
# Out:
# 5000
# 5005
# 5010
# 5015
# 5020
# 5025
# 5030
# 5035
# 5040
# 5045
# 5050
# 5055
# 5060
# 5065
# 5070
# 5075
# 5080
# 5085
# 5090
# 5095
# 5100
# only 10 valid employee ids remaining
# 5105
# 5110
# 5115
# 5120
# 5125
# 5130
# 5135
# 5140
# 5145
# 5150
